# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Hurricane Dorian Example

# %%
df = pd.read_csv('master.csv')
df.head()

df2 = pd.read_csv('dorian_df.csv')

df2.drop(columns = ['zip', 'StateName'], inplace = True)
df2.head()
# Out:
#      2019-07    2019-08    2019-09   2019-10  dorian_affected  \
# 0  1040700.0   853700.0   984700.0  889700.0                0
# 1   417900.0   422800.0   414900.0  401000.0                0
# 2  1141500.0  1131600.0  1032600.0  985100.0                0
# 3   320500.0   314000.0   316200.0  313900.0                0
# 4   490000.0   466300.0   475200.0  458700.0                0
#
#    %_change_after_dorian
# 0              -0.145095
# 1              -0.040440
# 2              -0.137013
# 3              -0.020593
# 4              -0.063878

# %%
df['2019-07'] = df2['2019-07']
df['2019-08'] = df2['2019-08']
df['2019-09'] = df2['2019-09']
df['2019-10'] = df2['2019-10']
df['dorian_affected'] = df2['dorian_affected']
df['%_change_after_dorian'] = df2['%_change_after_dorian']

df.head()
# Out:
#      zip StateName  pop_rank  2008 mean_median  2009 mean_median  \
# 0  10025  New York         1               NaN               NaN
# 1  60657  Illinois         2          376660.0     380441.666667
# 2  10023  New York         3               NaN               NaN
# 3  77494     Texas         4          243110.0     246758.333333
# 4  60614  Illinois         5               NaN               NaN
#
#    2010 mean_median  2011 mean_median  2012 mean_median  2013 mean_median  \
# 0               NaN               NaN               NaN               NaN
# 1     380441.666667     377933.333333     350575.000000     356400.000000
# 2               NaN               NaN               NaN               NaN
# 3     246758.333333     244550.000000     252083.333333     263333.333333
# 4               NaN               NaN               NaN               NaN
#
#    2014 mean_median  ...  2019 mean_median  dorian_affected  \
# 0               NaN  ...      9.713083e+05                0
# ...

# %%
dorian = df[df['dorian_affected'] == 1]
dorian.drop(columns =['sandy_affected', '%_change_after_sandy', 'harvey_affected'], inplace = True)
dorian.head()
# Out:
# /Users/rosedennis/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:4117: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#       zip StateName  pop_rank  2008 mean_median  2009 mean_median  \
# 51  33160   Florida        52               NaN          243350.0
# 58  33411   Florida        59          208200.0          130150.0
# 62  33025   Florida        63               NaN               NaN
# 66  33139   Florida        67               NaN               NaN
# 87  32210   Florida        88               NaN               NaN
#
#     2010 mean_median  2011 mean_median  2012 mean_median  2013 mean_median  \
# 51          243350.0          221100.0     264758.333333     275758.333333
# 58          130150.0           89050.0     103583.333333     137000.000000
# ...

# %%
#mean %_change_after_dorian
dorian['%_change_after_dorian'].mean()
# Out:
# 0.009910355577913216

# %% [markdown]
# We note that the mean percent changed because of hurricane Dorian wasn't that substantial.

# %%
dorian['%_change_after_dorian'].max()
# Out:
# 0.2677469135802469

# %%
dorian[dorian['%_change_after_dorian'] == 0.2677469135802469]
# Out:
#         zip StateName  pop_rank  2008 mean_median  2009 mean_median  \
# 6198  32736   Florida      6199               NaN               NaN
#
#       2010 mean_median  2011 mean_median  2012 mean_median  2013 mean_median  \
# 6198               NaN               NaN          152525.0          186875.0
#
#       2014 mean_median  ...  2016 mean_median  2017 mean_median  \
# 6198          198775.0  ...     232891.666667     249516.666667
#
#       2018 mean_median  2019 mean_median  dorian_affected  \
# 6198     276916.666667     285383.333333                1
#
#       %_change_after_dorian   2019-07   2019-08   2019-09   2019-10
# 6198               0.267747  259200.0  263000.0  296500.0  328600.0
#
# [1 rows x 21 columns]

# %% [markdown]
# The max positive percent change is around 27% in the city of Eustis.

# %%
dorian['%_change_after_dorian'].min()
# Out:
# -0.2079318013343217

# %%
dorian[dorian['%_change_after_dorian'] == -0.2079318013343217]
# Out:
#         zip StateName  pop_rank  2008 mean_median  2009 mean_median  \
# 6487  32124   Florida      6488               NaN               NaN
#
#       2010 mean_median  2011 mean_median  2012 mean_median  2013 mean_median  \
# 6487               NaN               NaN               NaN               NaN
#
#       2014 mean_median  ...  2016 mean_median  2017 mean_median  \
# 6487               NaN  ...     204591.666667     220416.666667
#
#       2018 mean_median  2019 mean_median  dorian_affected  \
# 6487     222483.333333     245508.333333                1
#
#       %_change_after_dorian   2019-07   2019-08   2019-09   2019-10
# 6487              -0.207932  269800.0  259000.0  227400.0  213700.0
#
# [1 rows x 21 columns]

# %% [markdown]
# The max negative percent change is around -21% in the city of Daytona beach

# %%
plt.scatter(dorian['zip'], dorian['%_change_after_dorian']);
#plt.savefig('percent_change_scatter.png')

# %% [markdown]
# This scatterplot shows that there doesn't seem to be that much of an impact on property value.

# %%
#I wanted to include the min/max percent change zipcodes
#row w/ max % change
plt.figure(figsize=(12,8))
plt.title('Mean_Median values for 5 zip codes affected by Dorian')
row = dorian.loc[6198]
plt.plot(row[3:15]);
#row w/ min % change
row2 = dorian.loc[6487]
plt.plot(row2[3:15]);
row3 = dorian.loc[3226]
plt.plot(row3[3:15]);
row4 = dorian.loc[1570]
plt.plot(row4[3:15]);
row5 = dorian.loc[2200]
plt.plot(row5[3:15]);
plt.legend( ['Eustis', 'Daytona Beach', 'Hollywood', 'River Park', 'Miami']);
plt.xticks(rotation = 45);
plt.tight_layout;
#plt.savefig('dorian_trends.png', bbox_inches="tight")

# %% [markdown]
# Couple things to note here:
# - the NA values in the dataset make it hard to interpret overall trends
# - mostly random sample of zipcodes display very different trends
# - each zipcode has a certain range, some bigger than others
# - can't see the min/max percent change cuz this plots years, not months

# %% [markdown]
# # National Trends

# %%
df.head()
# Out:
#      zip StateName  pop_rank  2008 mean_median  2009 mean_median  \
# 0  10025  New York         1               NaN               NaN
# 1  60657  Illinois         2          376660.0     380441.666667
# 2  10023  New York         3               NaN               NaN
# 3  77494     Texas         4          243110.0     246758.333333
# 4  60614  Illinois         5               NaN               NaN
#
#    2010 mean_median  2011 mean_median  2012 mean_median  2013 mean_median  \
# 0               NaN               NaN               NaN               NaN
# 1     380441.666667     377933.333333     350575.000000     356400.000000
# 2               NaN               NaN               NaN               NaN
# 3     246758.333333     244550.000000     252083.333333     263333.333333
# 4               NaN               NaN               NaN               NaN
#
#    2014 mean_median  ...  2019 mean_median  dorian_affected  \
# 0               NaN  ...      9.713083e+05                0
# ...

# %%
#randomly selecting 5 zipcodes from the nation
df.sample(5)
# Out:
#         zip    StateName  pop_rank  2008 mean_median  2009 mean_median  \
# 2050   6513  Connecticut      2051               NaN               NaN
# 1826  43402         Ohio      1827               NaN               NaN
# 206   90706   California       207               NaN               NaN
# 1685  46112      Indiana      1686          141890.0          139775.0
# 6269   7417   New Jersey      6270               NaN               NaN
#
#       2010 mean_median  2011 mean_median  2012 mean_median  2013 mean_median  \
# 2050               NaN               NaN               NaN               NaN
# 1826               NaN               NaN          143675.0     142041.666667
# 206                NaN               NaN               NaN               NaN
# 1685          139775.0     144558.333333          136975.0     153108.333333
# 6269               NaN               NaN               NaN               NaN
#
#       2014 mean_median  ...  2019 mean_median  dorian_affected  \
# ...

# %%
#random 5 zipcodes to get a sense of national trends
plt.figure(figsize=(12,8))
plt.title('Mean_Median values for 5 national zip codes')
#Texas
row = df.loc[3]
plt.plot(row[3:15]);
#California
row2 = df.loc[525]
plt.plot(row2[3:15]);
#Ohio
row3 = df.loc[3940]
plt.plot(row3[3:15]);
#Washington
row4 = df.loc[2460]
plt.plot(row4[3:15]);
#Pennsylvania
row5 = df.loc[634]
plt.plot(row5[3:15]);
plt.legend( ['Texas', 'California', 'Ohio', 'Washington', 'Pennsylvania']);
plt.xticks(rotation = 45);
plt.tight_layout;
#plt.savefig('national_trends.png', bbox_inches="tight")

# %% [markdown]
# # Narrowing down to the months near the occurrence of the hurricane

# %%
df = pd.read_csv('Sale_median_Prices_ZipCode_2_minor_cleaning.csv')
df.drop(columns = ['Unnamed: 0'], inplace = True)
zips = pd.read_csv('Dorian_zip.csv')

# %%
df['zip'] = df['zip'].astype(str)
df['zip'] = df['zip'].str[:5]

zips['0'] = zips['0'].astype(str)

# %%
dorian = []
for i in df['zip']:
    if i in set(zips['0']):
        dorian.append(1)
    else:
        dorian.append(0)

# %%
df['dorian_affected'] = dorian

df2 = df[df['dorian_affected']==1]

# %%
df2.sample(5)
# Out:
#       RegionID    zip StateName  pop_rank   2008-03   2008-04   2008-05  \
# 1131     71903  32257   Florida      1132  194000.0  186400.0  181400.0
# 2503     72387  33055   Florida      2504       NaN       NaN       NaN
# 1263     73010  34119   Florida      1264  349700.0  320800.0  307800.0
# 3970     72396  33067   Florida      3971       NaN       NaN       NaN
# 66       72442  33139   Florida        67       NaN       NaN       NaN
#
#        2008-06   2008-07   2008-08  ...   2019-04   2019-05   2019-06  \
# 1131  177200.0  173700.0  171800.0  ...  218400.0  206000.0  209400.0
# 2503       NaN       NaN       NaN  ...  259400.0  260600.0  254500.0
# 1263  341500.0  352700.0  353200.0  ...  380100.0  387000.0  397000.0
# 3970       NaN       NaN       NaN  ...  462100.0  460500.0  451200.0
# 66         NaN       NaN       NaN  ...  331800.0  299000.0  276200.0
#
#        2019-07   2019-08   2019-09   2019-10   2019-11   2019-12  \
# ...

# %%
plt.figure(figsize=(12,8))
plt.title('Monthly Median values for Dorian')
#max %change
row = df2.loc[6198]
plt.plot(row[140:146]);
row = df2.loc[3279]
plt.plot(row[140:146]);
row = df2.loc[2637]
plt.plot(row[140:146]);
#max negative %change
row = df2.loc[6487]
plt.plot(row[140:146]);
row = df2.loc[1137]
plt.plot(row[140:146]);
plt.legend( ['Eustis', 'Jacksonville', 'Melbourne', 'Daytona Beach', 'Orlando']);
plt.xticks(rotation = 45);
plt.tight_layout;
plt.savefig('dorian_month_trends.png', bbox_inches="tight")
